# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.bar(['pop','rock','jazz'],[10,20,30] ,width=0.5, align='edge')
plt.bar(['pop','rock','jazz'],[23,45,56] ,width=-0.5, align='edge')
plt.title('Songs Count by Genre')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.legend(['Mice','moon children'] , loc='upper right')

# %%
plt.plot([1,2,3,4],[10,20,0,40])

# %%
pd.options.display.max_columns = None
pd.options.display.max_colwidth = None
url_tracks = 'https://s3.eu-west-1.amazonaws.com/data.cyber.org.il/virtual_courses/introdata/colab/spotify_tracks1.csv'
url_artists = 'https://s3.eu-west-1.amazonaws.com/data.cyber.org.il/virtual_courses/introdata/colab/artists.csv'

# %%
tracks=pd.read_csv(url_tracks)
artists=pd.read_csv(url_artists)

# %%
tracks.head()
# Out:
#                                   name          artists
# 0                                Carve              Uli  \
# 1  Capítulo 2.16 - Banquero Anarquista  Fernando Pessoa
# 2   Vivo para Quererte - Remasterizado  Ignacio Corsini
# 3        El Prisionero - Remasterizado  Ignacio Corsini
# 4                  Lady of the Evening      Dick Haymes
#
#                id_artists  release_year  popularity  duration_minutes    key
# 0  45tIt06XoI0Iio4LBEVpls          1922           6          2.115050     Do  \
# 1  14jtPCOoNZwquk5wd9DxrY          1922           0          1.636667     Do
# 2  5LiOoJbxVSAMkBS2fUm3X2          1922           0          3.027333  Re(b)
# 3  5LiOoJbxVSAMkBS2fUm3X2          1922           0          2.948450    Sol
# 4  3BiJGZsyX9sJchTqcSA7Su          1922           0          2.718000  Mi(b)
#
#    mode  explicit  danceability  energy  loudness  speechiness  acousticness
# 0     1         0         0.645  0.4450   -13.338       0.4510         0.674  \
# 1     1         0         0.695  0.2630   -22.136       0.9570         0.797
# 2     1         0         0.434  0.1770   -21.180       0.0512         0.994
# 3     1         0         0.321  0.0946   -27.961       0.0504         0.995
# 4     0         0         0.402  0.1580   -16.900       0.0390         0.989
#
#    instrumentalness  liveness  valence    tempo
# 0            0.7440     0.151    0.127  104.851
# 1            0.0000     0.148    0.655  102.009
# 2            0.0218     0.212    0.457  130.418
# 3            0.9180     0.104    0.397  169.980
# 4            0.1300     0.311    0.196  103.220

# %%
artists.head()
# Out:
#                        id  followers genres
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []  \
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
tracks_artists = pd.merge(left=tracks, right=artists, left_on='id_artists', right_on='id')
tracks_artists.loc[tracks_artists['artists']=='Arik Einstein',:].head()
# Out:
#                        name_x        artists              id_artists
# 114215  הימים הארוכים העצובים  Arik Einstein  16XberediOtO5CaMrx85cR  \
# 114216                רוח רוח  Arik Einstein  16XberediOtO5CaMrx85cR
# 114219                Sa Leat  Arik Einstein  16XberediOtO5CaMrx85cR
# 114229            מה שהיה היה  Arik Einstein  16XberediOtO5CaMrx85cR
# 114236             Don Kishot  Arik Einstein  16XberediOtO5CaMrx85cR
#
#         release_year  popularity_x  duration_minutes key  mode  explicit
# 114215          1968            33          3.550000  Re     0         0  \
# 114216          1968            32          3.561550  Do     1         0
# 114219          1974            42          4.296700  Do     1         0
# 114229          1968            21          3.417117  Re     0         0
# 114236          1972            24          3.569200  Fa     1         0
#
#         danceability  energy  loudness  speechiness  acousticness
# 114215         0.462   0.388   -13.023       0.0375         0.336  \
# 114216         0.601   0.506   -14.175       0.0345         0.744
# 114219         0.409   0.377   -13.552       0.0346         0.622
# 114229         0.526   0.308   -15.515       0.0407         0.175
# 114236         0.578   0.331   -14.938       0.0312         0.695
#
#         instrumentalness  liveness  valence    tempo                      id
# 114215          0.000051    0.1030    0.606   96.479  16XberediOtO5CaMrx85cR  \
# 114216          0.000006    0.1130    0.936  139.362  16XberediOtO5CaMrx85cR
# 114219          0.000205    0.1070    0.513  156.291  16XberediOtO5CaMrx85cR
# 114229          0.000003    0.2090    0.440  114.099  16XberediOtO5CaMrx85cR
# 114236          0.004560    0.0742    0.432   98.325  16XberediOtO5CaMrx85cR
#
#         followers
# 114215   319224.0  \
# 114216   319224.0
# 114219   319224.0
# 114229   319224.0
# 114236   319224.0
#
#                                                                       genres
# 114215  ['classic israeli pop', 'israeli rock', 'israeli singer-songwriter']  \
# 114216  ['classic israeli pop', 'israeli rock', 'israeli singer-songwriter']
# 114219  ['classic israeli pop', 'israeli rock', 'israeli singer-songwriter']
# 114229  ['classic israeli pop', 'israeli rock', 'israeli singer-songwriter']
# 114236  ['classic israeli pop', 'israeli rock', 'israeli singer-songwriter']
#
#                name_y  popularity_y
# 114215  Arik Einstein            53
# 114216  Arik Einstein            53
# 114219  Arik Einstein            53
# 114229  Arik Einstein            53
# 114236  Arik Einstein            53

# %%
print('left',tracks.shape)
print('right',artists.shape)
print('merge',tracks_artists.shape)
# Out:
# left (521260, 18)
# right (1104349, 5)
# merge (509541, 23)

# %%
tracks_artists.head(100)
# Out:
#                                 name_x          artists
# 0                                Carve              Uli  \
# 1                             Lazy Boi              Uli
# 2                               Sketch              Uli
# 3                             Graphite              Uli
# 4                            Car Loans              Uli
# ..                                 ...              ...
# 95             Vencida - Remasterizado  Ignacio Corsini
# 96  Sacate la Caretita - Remasterizado  Ignacio Corsini
# 97      La Garconniere - Remasterizado  Ignacio Corsini
# 98            Juventud - Remasterizado  Ignacio Corsini
# 99         Beso de Sol - Remasterizado  Ignacio Corsini
#
#                 id_artists  release_year  popularity_x  duration_minutes
# 0   45tIt06XoI0Iio4LBEVpls          1922             6          2.115050  \
# 1   45tIt06XoI0Iio4LBEVpls          1922             0          2.622217
# 2   45tIt06XoI0Iio4LBEVpls          1922             0          1.450667
# 3   45tIt06XoI0Iio4LBEVpls          1922             0          1.740000
# 4   45tIt06XoI0Iio4LBEVpls          1922             0          2.880050
# ..                     ...           ...           ...               ...
# 95  5LiOoJbxVSAMkBS2fUm3X2          1923             0          2.001550
# 96  5LiOoJbxVSAMkBS2fUm3X2          1923             0          2.969117
# 97  5LiOoJbxVSAMkBS2fUm3X2          1923             0          2.510667
# 98  5LiOoJbxVSAMkBS2fUm3X2          1923             0          2.552450
# 99  5LiOoJbxVSAMkBS2fUm3X2          1923             0          2.447117
#
#       key  mode  explicit  danceability   energy  loudness  speechiness
# 0      Do     1         0         0.645  0.44500   -13.338       0.4510  \
# 1   Re(b)     1         0         0.298  0.46000   -18.645       0.4530
# 2      Fa     0         0         0.634  0.00399   -29.973       0.0377
# 3     Sol     1         0         0.644  0.68400    -8.247       0.1990
# 4   Si(b)     0         0         0.651  0.57400   -11.999       0.1040
# ..    ...   ...       ...           ...      ...       ...          ...
# 95     Si     1         0         0.572  0.09090   -24.536       0.1390
# 96     Fa     0         0         0.574  0.01190   -28.427       0.1020
# 97     Re     0         0         0.493  0.10900   -23.485       0.4230
# 98  Re(b)     0         0         0.415  0.03590   -29.191       0.0562
# 99    Sol     1         0         0.391  0.14300   -23.364       0.0425
#
#     acousticness  instrumentalness  liveness  valence    tempo
# 0          0.674             0.744    0.1510    0.127  104.851  \
# 1          0.521             0.856    0.4360    0.402   87.921
# 2          0.926             0.919    0.1050    0.396   79.895
# 3          0.144             0.802    0.0847    0.138  100.031
# 4          0.474             0.713    0.0597    0.412   99.878
# ..           ...               ...       ...      ...      ...
# 95         0.996             0.908    0.2460    0.570  131.550
# 96         0.996             0.936    0.0990    0.660  125.425
# 97         0.996             0.822    0.4000    0.599  120.344
# 98         0.996             0.914    0.1050    0.253   70.347
# 99         0.994             0.318    0.1470    0.549   78.544
#
#                         id  followers                      genres
# 0   45tIt06XoI0Iio4LBEVpls       91.0                          []  \
# 1   45tIt06XoI0Iio4LBEVpls       91.0                          []
# 2   45tIt06XoI0Iio4LBEVpls       91.0                          []
# 3   45tIt06XoI0Iio4LBEVpls       91.0                          []
# 4   45tIt06XoI0Iio4LBEVpls       91.0                          []
# ..                     ...        ...                         ...
# 95  5LiOoJbxVSAMkBS2fUm3X2     3528.0  ['tango', 'vintage tango']
# 96  5LiOoJbxVSAMkBS2fUm3X2     3528.0  ['tango', 'vintage tango']
# 97  5LiOoJbxVSAMkBS2fUm3X2     3528.0  ['tango', 'vintage tango']
# 98  5LiOoJbxVSAMkBS2fUm3X2     3528.0  ['tango', 'vintage tango']
# 99  5LiOoJbxVSAMkBS2fUm3X2     3528.0  ['tango', 'vintage tango']
#
#              name_y  popularity_y
# 0               Uli             4
# 1               Uli             4
# 2               Uli             4
# 3               Uli             4
# 4               Uli             4
# ..              ...           ...
# 95  Ignacio Corsini            23
# 96  Ignacio Corsini            23
# 97  Ignacio Corsini            23
# 98  Ignacio Corsini            23
# 99  Ignacio Corsini            23
#
# [100 rows x 23 columns]

# %%
# Filter the DataFrame to include only rows where 'genres' is 'metal'
metal_tracks_artists = tracks_artists.loc[tracks_artists['genres'] == 'chinese viral pop'].head(100)

# Display the filtered DataFrame
# Out:
# Empty DataFrame
# Columns: [name_x, artists, id_artists, release_year, popularity_x, duration_minutes, key, mode, explicit, danceability, energy, loudness, speechiness, acousticness, instrumentalness, liveness, valence, tempo, id, followers, genres, name_y, popularity_y]
# Index: []

# %%
metal_yes_no=['metal' in genre for genre in tracks['genres']]

# %%
print=[metal_yes_no]
